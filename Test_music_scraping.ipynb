# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/shared/Elections2024/Data/1_Processed_Raw/TikTok/master_tiktok_df.csv",
                dtype= {"music_id":str})

# %%
df = df.drop_duplicates("tiktokurl")
